# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I choose the Ranking Signal Analysis lane because it produces clear but valuable deliverables (including a signal report and a few charts to visualise data), which gives valuable insights on which signals can be associated with visibility, clicks, or engagement. Therefore, organisation or site editors can modify their websites accordingly.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# This work would improve the decision on which content archetypes and signal profiles perform the best and where to allocate resources. The website manager or content lead would act on this decision by identifying and recommending which content to prioritise. However, the cost of a wrong recommendation is resource andd time wastage, missed opportunities, and compounded effort.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# Data loading
import pandas as pd
url = "https://raw.githubusercontent.com/reezcon/First-ML-Pipeline/main/data/raw/content_refresh_anonymized.csv"
df = pd.read_csv(url)

print ("Dataset size:", df.shape)
print ("First 5 rows:")
print (df.head())
# Out:
# Dataset size: (30000, 44)
# First 5 rows:
#              content_id          client_id  search_volume  competition  \
# 0  content_304f48230142  client_f369cb89fc           10.0         0.67
# 1  content_a1fb4e703a9e  client_4e07408562           90.0         0.01
# 2  content_9aa793d4d895  client_7f2253d7e2            0.0         0.00
# 3  content_331d6c4de07b  client_19581e27de           10.0         0.00
# 4  content_d99b7a2d90ca  client_3fdba35f04            0.0         0.00
#
#   competition_level   cpc     content_type    main_intent  word_count  \
# 0              HIGH  2.05  keyword article  transactional      3221.0
# 1               LOW  0.05  keyword article  informational      2481.0
# 2               LOW  0.00  keyword article  informational      3515.0
# 3               LOW  0.00  keyword article     commercial         NaN
# 4               LOW  0.00  keyword article  informational      2803.0
#
# ...

# %%
# CTR by position (group pages by their search position and calculate average CTR)

position_stats = df.groupby("position_tier")["ctr"].mean().sort_values(ascending=False)

print(position_stats)
# Out:
# position_tier
# top_3       1.483611
# page_1      0.652467
# striking    0.323239
# page_3_5    0.222484
# deep        0.150212
# Name: ctr, dtype: float64

# %%
# Engagement by freshness (comparing pages that were recently updated vs old pages)

freshness_stats = df.groupby("freshness_tier")["engagement_rate"].mean().sort_values(ascending=False)

print(freshness_stats)
# Out:
# freshness_tier
# 0-30      2.599727
# 91-180    2.406133
# 31-90     2.134971
# 181+      2.028333
# Name: engagement_rate, dtype: float64

# %%
# The performance of different content types

content_stats = df.groupby("content_type")["engagement_rate"].mean().sort_values(ascending=False)

print(content_stats)
# Out:
# content_type
# keyword article       2.649161
# feedly article        1.791450
# comparison article    0.294118
# Name: engagement_rate, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
